# %%
import pandas as pd
import numpy as np
import polars as pl
import gc
import pyarrow
from pathlib import Path #to keep importing datasets from relative paths consistent across OS
import plotly
import plotly.express as px
import nbformat
import plotly.io as pio
import kaleido

# %%
#Get current notebook directory
current_dir = Path(__file__).parent if "__file__" in globals() else Path.cwd()

# Define path relative to project root
data_path = current_dir.parent.parent / "data"

# %%
#current_directory = Path.cwd()
data_path = '../ML_proj_data/ml-32m/'

links_data_path = data_path + 'links.csv'
movies_data_path = data_path + 'movies.csv'
ratings_data_path = data_path + 'ratings.csv'
tags_data_path = data_path + 'tags.csv'

#pull CSV files in

links_data = pd.read_csv(links_data_path) #infers whether it has columns or not
movies_data = pd.read_csv(movies_data_path) 
ratings_data = pd.read_csv(ratings_data_path) 
tags_data = pd.read_csv(tags_data_path)

# %%
sample_ratings = ratings_data.sample(n=150000, replace=False, random_state=158, axis = 0)
movies = pd.merge(pd.merge(pd.merge(sample_ratings, tags_data, on='movieId'), movies_data, on='movieId'), links_data, on='movieId')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 sample_ratings = ratings_data.sample(n=150000, replace=False, random_state=158, axis = 0)
# ----> 2 movies = pd.merge(pd.merge(pd.merge(sample_ratings, tags_data, on='movieId'), movies_data, on='movieId'), links_data, on='movieId')
#
# File ~\anaconda3\envs\ML_6740_HW1\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\anaconda3\envs\ML_6740_HW1\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
# ...
